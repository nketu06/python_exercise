# %%
# How Python Uses Memory
# Python objects have overhead.

# Example:

import sys
print(sys.getsizeof(1))  # ~28 bytes
# Out:
# 28

# %%
# tracemalloc ⭐⭐⭐⭐⭐
# Track memory usage in Python.
# Example

import tracemalloc

tracemalloc.start()

data = [x for x in range(100000)]

current, peak = tracemalloc.get_traced_memory()

print(current, peak)

tracemalloc.stop()
# Out:
# 2050 24924

# %% [markdown]
# tracemalloc = memory tracking.
# generator > list (memory)
# slots = memory optimization
# GC = handles cycles
