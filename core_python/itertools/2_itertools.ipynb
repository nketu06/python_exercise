# %%
import itertools

counter = itertools.count()
# infinte value
# for num in counter:
#     print(num)

# %%
print(list(zip(itertools.count(1),[100,499,933])))
# Out:
# [(1, 100), (2, 499), (3, 933)]

# %%
print(type(itertools.cycle(["on","off"])))
# Out:
# <class 'itertools.cycle'>

# %%
letter=['a','b','c']
num=[1,2,3,4]
print(list(itertools.chain(num,letter,num)))
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c', 1, 2, 3, 4]

# %%
# used to slice iterator
print(list(itertools.islice(range(10),3,5)))
# Out:
# [3, 4]

# %%
with open('test.log','r') as f:
    print(type(f))
    header = itertools.islice(f,2)

    for line in header:
        print(line,end=' ')
# Out:
# <class '_io.TextIOWrapper'>
# hello i am a log file,
#  i am here for testing
