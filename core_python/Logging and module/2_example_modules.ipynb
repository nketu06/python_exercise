# %% [markdown]
# Module vs Package
#
# Module
# - A single .py file
#
# Package
# - A folder containing multiple modules

# %%
# my_app/  
#     __init__.py  
#     utils.py 
#     db.py  

# __init__.py
# Marks directory as a Python package.

# %%
# Absolute Import (BEST PRACTICE)

# from my_app.utils import func

# %% [markdown]
# How Python Resolves Imports
#
# Python searches in:
#
# - 1️⃣ current directory
# - 2️⃣ PYTHONPATH
# - 3️⃣ site-packages

# %%
import sys
print(sys.path)
# Out:
# ['/Library/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Users/nishantketu/workspace/python/.venv/lib/python3.13/site-packages']
